# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# Very hacky, bad thing to do.
SRC_PATH = os.path.realpath('../src')
sys.path.append(SRC_PATH)

# %%
# Local imports.
from analysis import single_cycles
from defaults import PITCH_RATE, SAMPLE_RATE
from synthesis import EnvelopeMorpher, StimulusGenerator
from util import midi_to_hz, time_plot, stft_plot

# %%
# Load env as linear amplitude. (CheapTrick calculates the power spectrum.)
env = single_cycles[0]['env']
env = np.sqrt(env)

# %%
morpher = EnvelopeMorpher(env)

morpher.show(zoom=8)

# %%
# Demonstration of random partials amplitude.

morpher.rap()
morpher.shuffle_phase(num_shifts=4)
morpher.show(zoom=8)

# %%
# Printing instance outputs log of morph history.

print(morpher)
# Out:
# Summary
# -------
#
# Total morphs:	2
#
# {'bin': 0, 'mod_gain': 1.4380440006590534}
# {'bin': 1, 'mod_gain': 6.145460795349447}
# {'bin': 2, 'mod_gain': 4.084037455885725}
# {'bin': 3, 'mod_gain': 1.19409964767908}
# {'bin': 4, 'mod_gain': 8.328804937626993}
# {'bin': 5, 'mod_gain': 4.401512432732715}
# {'bin': 6, 'mod_gain': 4.65827570977139}
# {'bin': 7, 'mod_gain': 5.840407753223217}
# {'bin': 8, 'mod_gain': 4.732923878572435}
# {'bin': 9, 'mod_gain': 0.08317024072438173}
# {'bin': 10, 'mod_gain': 4.97490710112197}
# {'bin': 11, 'mod_gain': 5.969885971587209}
# {'bin': 12, 'mod_gain': 5.752352989122459}
# {'bin': 13, 'mod_gain': 4.036122660811163}
# {'bin': 14, 'mod_gain': 6.140214858299967}
# {'bin': 15, 'mod_gain': 0.18456227336902442}
# {'bin': 16, 'mod_gain': 7.0826960044676}
# {'bin': 17, 'mod_gain': 3.8211020153405864}
# {'bin': 18, 'mod_gain': 3.817505201632434}
# {'bin': 19, 'mod_gain': 6.61962983218788}
# {'bin': 20, 'mod_gain': 4.3308575325128835}
# {'bin': 21, 'mod_gain': 4.090232132872769}
# {'bin': 22, 'mod_gain': 2.5524604234328363}
# {'bin': 23, 'mod_gain': 6.11352810622666}
# {'bin': 24, 'mod_gain': 7.959451064235328}
# {'bin': 25, 'mod_gain': 2.3466352796768755}
# {'bin': 26, 'mod_gain': 2.38545181121542}
# {'bin': 27, 'mod_gain': 5.303131862220328}
# {'bin': 28, 'mod_gain': 5.343656799528581}
# {'bin': 29, 'mod_gain': 6.101842768826165}
# {'bin': 30, 'mod_gain': 5.820928712219327}
# {'bin': 31, 'mod_gain': 3.633272552802697}
# {'bin': 32, 'mod_gain': 2.4531662306237623}
# {'bin': 33, 'mod_gain': 8.533670226046137}
# {'bin': 34, 'mod_gain': 6.730055736511005}
# {'bin': 35, 'mod_gain': 5.8398171315928735}
# {'bin': 36, 'mod_gain': 3.4267136470137336}
# {'bin': 37, 'mod_gain': 2.4071075445714616}
# {'bin': 38, 'mod_gain': 4.432371951165064}
# {'bin': 39, 'mod_gain': 9.383673063301263}
# {'bin': 40, 'mod_gain': 7.117745351056771}
# {'bin': 41, 'mod_gain': 3.537168010318057}
# {'bin': 42, 'mod_gain': 4.280219768200537}
# {'bin': 43, 'mod_gain': 0.9507591776714797}
# {'bin': 44, 'mod_gain': 2.8344600938767286}
# {'bin': 45, 'mod_gain': 3.4516943770820507}
# {'bin': 46, 'mod_gain': 7.60185950310248}
# {'bin': 47, 'mod_gain': 3.1245611891022196}
# {'bin': 48, 'mod_gain': 9.308944797832721}
# {'bin': 49, 'mod_gain': 2.146605645499257}
# {'bin': 50, 'mod_gain': 6.236261911650468}
# {'bin': 51, 'mod_gain': 8.21542408011574}
# {'bin': 52, 'mod_gain': 6.292315346862028}
# {'bin': 53, 'mod_gain': 1.5589962542926472}
# {'bin': 54, 'mod_gain': 2.3305987927421077}
# {'bin': 55, 'mod_gain': 4.848622136097979}
# {'bin': 56, 'mod_gain': 3.8104725095655487}
# {'bin': 57, 'mod_gain': 5.647317249061983}
# {'bin': 58, 'mod_gain': 1.2483719306052143}
# {'bin': 59, 'mod_gain': 8.056455546632549}
# {'bin': 60, 'mod_gain': 4.447096307359029}
# {'bin': 61, 'mod_gain': 7.622340317963423}
# {'bin': 62, 'mod_gain': 6.605175619080753}
# {'bin': 63, 'mod_gain': 8.443308671586472}
# {'bin': 64, 'mod_gain': 2.3086375958612493}
# {'bin': 65, 'mod_gain': 7.481176741376406}
# {'bin': 66, 'mod_gain': 8.055148796090053}
# {'bin': 67, 'mod_gain': 6.3202865004099404}
# {'bin': 68, 'mod_gain': 3.0477770598614615}
# {'bin': 69, 'mod_gain': 4.019964382086702}
# {'bin': 70, 'mod_gain': 2.1718965782255575}
# {'bin': 71, 'mod_gain': 7.093204787170581}
# {'bin': 72, 'mod_gain': 0.2626912581570706}
# {'bin': 73, 'mod_gain': 2.2193345778637785}
# {'bin': 74, 'mod_gain': 9.82020478281458}
# {'bin': 75, 'mod_gain': 8.151295075588006}
# {'bin': 76, 'mod_gain': 4.74739155829369}
# {'bin': 77, 'mod_gain': 5.354554632378771}
# {'bin': 78, 'mod_gain': 2.520594033794459}
# {'bin': 79, 'mod_gain': 8.789296349867055}
# {'bin': 80, 'mod_gain': 7.526490656957453}
# {'bin': 81, 'mod_gain': 6.661828815562847}
# {'bin': 82, 'mod_gain': 9.417356182245872}
# {'bin': 83, 'mod_gain': 4.607686879560365}
# {'bin': 84, 'mod_gain': 7.352764110444702}
# {'bin': 85, 'mod_gain': 1.7651126940852302}
# {'bin': 86, 'mod_gain': 6.204030565006949}
# {'bin': 87, 'mod_gain': 2.8862279974591596}
# {'bin': 88, 'mod_gain': 3.6344013873807093}
# {'bin': 89, 'mod_gain': 7.428394382477414}
# {'bin': 90, 'mod_gain': 7.391676654865991}
# {'bin': 91, 'mod_gain': 4.126663859921569}
# {'bin': 92, 'mod_gain': 2.840819878643601}
# {'bin': 93, 'mod_gain': 4.753118923427761}
# {'bin': 94, 'mod_gain': 0.6716459376894979}
# {'bin': 95, 'mod_gain': 3.5050487307977853}
# {'bin': 96, 'mod_gain': 6.859398519490162}
# {'bin': 97, 'mod_gain': 6.668734625039276}
# {'bin': 98, 'mod_gain': 8.432231012162}
# {'bin': 99, 'mod_gain': 7.997145182869919}
# {'bin': 100, 'mod_gain': 5.132639334044037}
# {'bin': 101, 'mod_gain': 8.526258139621097}
# {'bin': 102, 'mod_gain': 0.641952376351469}
# {'bin': 103, 'mod_gain': 8.040147159214188}
# {'bin': 104, 'mod_gain': 0.5874473438095595}
# {'bin': 105, 'mod_gain': 9.729110265662852}
# {'bin': 106, 'mod_gain': 4.961584073838193}
# {'bin': 107, 'mod_gain': 6.616051964486256}
# {'bin': 108, 'mod_gain': 0.3846796499839089}
# {'bin': 109, 'mod_gain': 5.339583222927463}
# {'bin': 110, 'mod_gain': 2.85805184292654}
# {'bin': 111, 'mod_gain': 1.2349407893116704}
# {'bin': 112, 'mod_gain': 6.133035810563641}
# {'bin': 113, 'mod_gain': 2.8419623241706704}
# {'bin': 114, 'mod_gain': 6.648604350407514}
# {'bin': 115, 'mod_gain': 1.3582673911946785}
# {'bin': 116, 'mod_gain': 1.6922815750207476}
# {'bin': 117, 'mod_gain': 9.21495123673476}
# {'bin': 118, 'mod_gain': 4.03553051985366}
# {'bin': 119, 'mod_gain': 4.305546863970639}
# {'bin': 120, 'mod_gain': 9.905722894569962}
# {'bin': 121, 'mod_gain': 2.182829293600832}
# {'bin': 122, 'mod_gain': 0.3930774034086504}
# {'bin': 123, 'mod_gain': 9.957427252829618}
# {'bin': 124, 'mod_gain': 5.493700861046696}
# {'bin': 125, 'mod_gain': 8.590695503528233}
# {'bin': 126, 'mod_gain': 5.9812707655118995}
# {'bin': 127, 'mod_gain': 9.532499808207044}
# {'bin': 128, 'mod_gain': 8.747565305595328}
# {'bin': 129, 'mod_gain': 4.249076433756876}
# {'bin': 130, 'mod_gain': 2.084758645059935}
# {'bin': 131, 'mod_gain': 5.8134009171893775}
# {'bin': 132, 'mod_gain': 9.050704572478589}
# {'bin': 133, 'mod_gain': 2.8929590755602472}
# {'bin': 134, 'mod_gain': 3.5249479164506137}
# {'bin': 135, 'mod_gain': 5.23649680682357}
# {'bin': 136, 'mod_gain': 3.8342674543666924}
# {'bin': 137, 'mod_gain': 7.777842154124281}
# {'bin': 138, 'mod_gain': 9.993606065600387}
# {'bin': 139, 'mod_gain': 6.764959892333977}
# {'bin': 140, 'mod_gain': 7.9147453069279905}
# {'bin': 141, 'mod_gain': 0.7109232763188478}
# {'bin': 142, 'mod_gain': 8.917306883359101}
# {'bin': 143, 'mod_gain': 2.565735110825477}
# {'bin': 144, 'mod_gain': 7.3019903164985145}
# {'bin': 145, 'mod_gain': 5.153209070695524}
# {'bin': 146, 'mod_gain': 0.09845577003220862}
# {'bin': 147, 'mod_gain': 2.140999310574223}
# {'bin': 148, 'mod_gain': 4.831425626972373}
# {'bin': 149, 'mod_gain': 6.320499125182028}
# {'bin': 150, 'mod_gain': 8.874162132811946}
# {'bin': 151, 'mod_gain': 9.005744451100961}
# {'bin': 152, 'mod_gain': 4.081881665177217}
# {'bin': 153, 'mod_gain': 7.909670474831772}
# {'bin': 154, 'mod_gain': 5.043308544655552}
# {'bin': 155, 'mod_gain': 9.146439818499974}
# {'bin': 156, 'mod_gain': 8.256479447714746}
# {'bin': 157, 'mod_gain': 4.796630419396043}
# {'bin': 158, 'mod_gain': 8.624072957148169}
# {'bin': 159, 'mod_gain': 6.004819511505078}
# {'bin': 160, 'mod_gain': 3.6502890525388985}
# {'bin': 161, 'mod_gain': 2.3548003081064293}
# {'bin': 162, 'mod_gain': 5.782976911375703}
# {'bin': 163, 'mod_gain': 6.033916189519392}
# {'bin': 164, 'mod_gain': 3.4329878706064134}
# {'bin': 165, 'mod_gain': 8.794268414685181}
# {'bin': 166, 'mod_gain': 6.853599537634093}
# {'bin': 167, 'mod_gain': 9.036607045742661}
# {'bin': 168, 'mod_gain': 3.642837622827313}
# {'bin': 169, 'mod_gain': 0.3807510834421868}
# {'bin': 170, 'mod_gain': 2.6921174368502254}
# {'bin': 171, 'mod_gain': 6.009752686688073}
# {'bin': 172, 'mod_gain': 5.863843900640218}
# {'bin': 173, 'mod_gain': 5.4788464536146115}
# {'bin': 174, 'mod_gain': 8.307974265778057}
# {'bin': 175, 'mod_gain': 2.1979486079096966}
# {'bin': 176, 'mod_gain': 5.268807640091735}
# {'bin': 177, 'mod_gain': 3.2075628003995496}
# {'bin': 178, 'mod_gain': 5.211871509214724}
# {'bin': 179, 'mod_gain': 6.840580108195691}
# {'bin': 180, 'mod_gain': 9.694190640466292}
# {'bin': 181, 'mod_gain': 7.5829836888017965}
# {'bin': 182, 'mod_gain': 8.553665085541521}
# {'bin': 183, 'mod_gain': 4.943307775545405}
# {'bin': 184, 'mod_gain': 0.11226799951843058}
# {'bin': 185, 'mod_gain': 1.4574976739847156}
# {'bin': 186, 'mod_gain': 4.038511593399395}
# {'bin': 187, 'mod_gain': 0.688360546923289}
# {'bin': 188, 'mod_gain': 8.535579507771825}
# {'bin': 189, 'mod_gain': 2.9955070013806417}
# {'bin': 190, 'mod_gain': 7.706476991800116}
# {'bin': 191, 'mod_gain': 7.225730306271446}
# {'bin': 192, 'mod_gain': 4.231385548837516}
# {'bin': 193, 'mod_gain': 4.247305110439767}
# {'bin': 194, 'mod_gain': 1.121156237299945}
# {'bin': 195, 'mod_gain': 3.461377746531844}
# {'bin': 196, 'mod_gain': 5.567531243581278}
# {'bin': 197, 'mod_gain': 9.612425004671929}
# {'bin': 198, 'mod_gain': 0.039061949610875724}
# {'bin': 199, 'mod_gain': 6.262343623605585}
# {'bin': 200, 'mod_gain': 9.338963502702608}
# {'bin': 201, 'mod_gain': 1.5845922696168613}
# {'bin': 202, 'mod_gain': 8.560849294572842}
# {'bin': 203, 'mod_gain': 0.17852226290583362}
# {'bin': 204, 'mod_gain': 2.958867969123534}
# {'bin': 205, 'mod_gain': 1.100765397323038}
# {'bin': 206, 'mod_gain': 6.418066497683364}
# {'bin': 207, 'mod_gain': 2.3489377556391777}
# {'bin': 208, 'mod_gain': 3.8111685210186708}
# {'bin': 209, 'mod_gain': 2.7056979523989044}
# {'bin': 210, 'mod_gain': 2.1199280731351755}
# {'bin': 211, 'mod_gain': 5.1339030604775635}
# {'bin': 212, 'mod_gain': 2.7725650249108735}
# {'bin': 213, 'mod_gain': 6.706589425184941}
# {'bin': 214, 'mod_gain': 6.022332988551326}
# {'bin': 215, 'mod_gain': 3.4666132844811215}
# {'bin': 216, 'mod_gain': 0.8380062466699423}
# {'bin': 217, 'mod_gain': 7.093270280598938}
# {'bin': 218, 'mod_gain': 3.1122377342109386}
# {'bin': 219, 'mod_gain': 4.913183789761657}
# {'bin': 220, 'mod_gain': 1.2795745883725196}
# {'bin': 221, 'mod_gain': 4.0295787186566585}
# {'bin': 222, 'mod_gain': 3.0711413434783807}
# {'bin': 223, 'mod_gain': 5.529150901503346}
# {'bin': 224, 'mod_gain': 1.5980372007027133}
# {'bin': 225, 'mod_gain': 1.1278363168795247}
# {'bin': 226, 'mod_gain': 1.9714139938683684}
# {'bin': 227, 'mod_gain': 4.549814288872614}
# {'bin': 228, 'mod_gain': 8.399914019934249}
# {'bin': 229, 'mod_gain': 3.20921937547734}
# {'bin': 230, 'mod_gain': 3.8046071037825557}
# {'bin': 231, 'mod_gain': 1.3364243257171848}
# {'bin': 232, 'mod_gain': 1.6337988097251255}
# {'bin': 233, 'mod_gain': 3.9838615195884053}
# {'bin': 234, 'mod_gain': 9.927575264024497}
# {'bin': 235, 'mod_gain': 7.640171026058812}
# {'bin': 236, 'mod_gain': 6.637672785193466}
# {'bin': 237, 'mod_gain': 8.97720583871415}
# {'bin': 238, 'mod_gain': 0.9072621906600997}
# {'bin': 239, 'mod_gain': 4.384293041763355}
# {'bin': 240, 'mod_gain': 8.22334861987358}
# {'bin': 241, 'mod_gain': 2.9996415448449163}
# {'bin': 242, 'mod_gain': 2.908096384956478}
# {'bin': 243, 'mod_gain': 2.732521859165603}
# {'bin': 244, 'mod_gain': 0.6258624565794968}
# {'bin': 245, 'mod_gain': 6.131597178672758}
# {'bin': 246, 'mod_gain': 9.71900715003083}
# {'bin': 247, 'mod_gain': 3.2558948430309744}
# {'bin': 248, 'mod_gain': 0.4321516775804768}
# {'bin': 249, 'mod_gain': 4.860500214907759}
# {'bin': 250, 'mod_gain': 8.441559990583533}
# {'bin': 251, 'mod_gain': 0.7088117698329865}
# {'bin': 252, 'mod_gain': 2.7907150871044917}
# {'bin': 253, 'mod_gain': 4.407480209216733}
# {'bin': 254, 'mod_gain': 6.547487319872617}
# {'bin': 255, 'mod_gain': 9.519988618670954}
# {'bin': 256, 'mod_gain': 6.206706428079459}
# {'bin': 257, 'mod_gain': 0.047689365819300056}
# {'bin': 258, 'mod_gain': 8.03433952265541}
# {'bin': 259, 'mod_gain': 4.8152001686944965}
# {'bin': 260, 'mod_gain': 7.838371335846195}
# {'bin': 261, 'mod_gain': 7.119600764444619}
# {'bin': 262, 'mod_gain': 0.2706552624836567}
# {'bin': 263, 'mod_gain': 0.9910937781233375}
# {'bin': 264, 'mod_gain': 7.7781648148163365}
# {'bin': 265, 'mod_gain': 4.171995735043799}
# {'bin': 266, 'mod_gain': 8.638697101878783}
# {'bin': 267, 'mod_gain': 9.35658783415044}
# {'bin': 268, 'mod_gain': 6.480266863599543}
# {'bin': 269, 'mod_gain': 5.663613639101319}
# {'bin': 270, 'mod_gain': 6.652479615171432}
# {'bin': 271, 'mod_gain': 4.777545656660984}
# {'bin': 272, 'mod_gain': 9.215142122457005}
# {'bin': 273, 'mod_gain': 5.609915790605147}
# {'bin': 274, 'mod_gain': 6.617304675202963}
# {'bin': 275, 'mod_gain': 3.93215206187443}
# {'bin': 276, 'mod_gain': 2.487414062987676}
# {'bin': 277, 'mod_gain': 0.8137431343000767}
# {'bin': 278, 'mod_gain': 1.805732385583475}
# {'bin': 279, 'mod_gain': 8.717149151706908}
# {'bin': 280, 'mod_gain': 4.107641432750566}
# {'bin': 281, 'mod_gain': 5.007162531993266}
# {'bin': 282, 'mod_gain': 5.450009602425665}
# {'bin': 283, 'mod_gain': 6.767964864276875}
# {'bin': 284, 'mod_gain': 4.355933282442219}
# {'bin': 285, 'mod_gain': 1.8761483309241034}
# {'bin': 286, 'mod_gain': 4.7958352405376035}
# {'bin': 287, 'mod_gain': 3.4070061172547197}
# {'bin': 288, 'mod_gain': 5.22274894676086}
# {'bin': 289, 'mod_gain': 4.744605965111149}
# {'bin': 290, 'mod_gain': 7.364554692451664}
# {'bin': 291, 'mod_gain': 2.1645717752223073}
# {'bin': 292, 'mod_gain': 2.7623215199069637}
# {'bin': 293, 'mod_gain': 2.88686094806104}
# {'bin': 294, 'mod_gain': 0.13371922285497884}
# {'bin': 295, 'mod_gain': 1.8842892494076502}
# {'bin': 296, 'mod_gain': 9.639529070967093}
# {'bin': 297, 'mod_gain': 8.18507203024664}
# {'bin': 298, 'mod_gain': 1.4347580802206705}
# {'bin': 299, 'mod_gain': 8.014248788234585}
# {'bin': 300, 'mod_gain': 6.486266410908902}
# {'bin': 301, 'mod_gain': 3.867224444906615}
# {'bin': 302, 'mod_gain': 2.722273402866012}
# {'bin': 303, 'mod_gain': 0.46492596092312266}
# {'bin': 304, 'mod_gain': 8.346780096099554}
# {'bin': 305, 'mod_gain': 9.507587507439204}
# {'bin': 306, 'mod_gain': 5.447437066210571}
# {'bin': 307, 'mod_gain': 2.937715641541966}
# {'bin': 308, 'mod_gain': 6.860182007517885}
# {'bin': 309, 'mod_gain': 8.487867592297109}
# {'bin': 310, 'mod_gain': 8.297845152230654}
# {'bin': 311, 'mod_gain': 1.867092111459543}
# {'bin': 312, 'mod_gain': 9.304193311711588}
# {'bin': 313, 'mod_gain': 3.0058072200709454}
# {'bin': 314, 'mod_gain': 8.525468204444856}
# {'bin': 315, 'mod_gain': 8.805863458386222}
# {'bin': 316, 'mod_gain': 1.6088182561166742}
# {'bin': 317, 'mod_gain': 4.949773849464012}
# {'bin': 318, 'mod_gain': 2.7421373882072766}
# {'bin': 319, 'mod_gain': 6.058064919494043}
# {'bin': 320, 'mod_gain': 8.61147807692356}
# {'bin': 321, 'mod_gain': 7.071906751415202}
# {'bin': 322, 'mod_gain': 5.842398868352276}
# {'bin': 323, 'mod_gain': 9.157264781175193}
# {'bin': 324, 'mod_gain': 9.782132792582098}
# {'bin': 325, 'mod_gain': 5.08562899828671}
# {'bin': 326, 'mod_gain': 4.860718245651033}
# {'bin': 327, 'mod_gain': 1.0553956408249987}
# {'bin': 328, 'mod_gain': 3.97247072468352}
# {'bin': 329, 'mod_gain': 4.417932158760043}
# {'bin': 330, 'mod_gain': 6.760386440327023}
# {'bin': 331, 'mod_gain': 5.913387764538735}
# {'bin': 332, 'mod_gain': 0.1584514333332554}
# {'bin': 333, 'mod_gain': 8.866410314071498}
# {'bin': 334, 'mod_gain': 8.927363753922013}
# {'bin': 335, 'mod_gain': 4.740251230904803}
# {'bin': 336, 'mod_gain': 1.2862568540290142}
# {'bin': 337, 'mod_gain': 1.3869977781588416}
# {'bin': 338, 'mod_gain': 6.642766400719236}
# {'bin': 339, 'mod_gain': 8.129196627489698}
# {'bin': 340, 'mod_gain': 1.7260510674384266}
# {'bin': 341, 'mod_gain': 8.010598400563188}
# {'bin': 342, 'mod_gain': 6.6063324487349675}
# {'bin': 343, 'mod_gain': 7.151658322838235}
# {'bin': 344, 'mod_gain': 1.3986738186333703}
# {'bin': 345, 'mod_gain': 6.483728476332109}
# {'bin': 346, 'mod_gain': 7.529813822886267}
# {'bin': 347, 'mod_gain': 7.7027211295947176}
# {'bin': 348, 'mod_gain': 1.4229700686988234}
# {'bin': 349, 'mod_gain': 4.329671685182584}
# {'bin': 350, 'mod_gain': 2.405879803630401}
# {'bin': 351, 'mod_gain': 2.203740177351823}
# {'bin': 352, 'mod_gain': 4.604597601795327}
# {'bin': 353, 'mod_gain': 1.0223373953997217}
# {'bin': 354, 'mod_gain': 8.175927728885197}
# {'bin': 355, 'mod_gain': 0.006828593379423209}
# {'bin': 356, 'mod_gain': 5.307171754481548}
# {'bin': 357, 'mod_gain': 4.482986158461491}
# {'bin': 358, 'mod_gain': 9.064623091918016}
# {'bin': 359, 'mod_gain': 3.1562801725396463}
# {'bin': 360, 'mod_gain': 4.366479728204929}
# {'bin': 361, 'mod_gain': 7.549814562389776}
# {'bin': 362, 'mod_gain': 1.5515593314951837}
# {'bin': 363, 'mod_gain': 2.289097330742119}
# {'bin': 364, 'mod_gain': 7.338600449151298}
# {'bin': 365, 'mod_gain': 2.605517456857384}
# {'bin': 366, 'mod_gain': 6.228126625903389}
# {'bin': 367, 'mod_gain': 4.2252624001768915}
# {'bin': 368, 'mod_gain': 0.16628163804952134}
# {'bin': 369, 'mod_gain': 3.821051979559118}
# {'bin': 370, 'mod_gain': 6.651537034601967}
# {'bin': 371, 'mod_gain': 3.852693458080365}
# {'bin': 372, 'mod_gain': 7.994397860203701}
# {'bin': 373, 'mod_gain': 5.190715913388534}
# {'bin': 374, 'mod_gain': 3.1985628440027902}
# {'bin': 375, 'mod_gain': 5.802647974172029}
# {'bin': 376, 'mod_gain': 4.49499590429059}
# {'bin': 377, 'mod_gain': 6.26335557876383}
# {'bin': 378, 'mod_gain': 5.205999912361216}
# {'bin': 379, 'mod_gain': 6.715678477598074}
# {'bin': 380, 'mod_gain': 1.3232486087647055}
# {'bin': 381, 'mod_gain': 5.882320699180151}
# {'bin': 382, 'mod_gain': 8.452204952777189}
# {'bin': 383, 'mod_gain': 0.021173284177444796}
# {'bin': 384, 'mod_gain': 6.45642429950966}
# {'bin': 385, 'mod_gain': 1.2637340219780135}
# {'bin': 386, 'mod_gain': 9.490943273917186}
# {'bin': 387, 'mod_gain': 5.520407945024511}
# {'bin': 388, 'mod_gain': 7.53034521919823}
# {'bin': 389, 'mod_gain': 3.374361907069059}
# {'bin': 390, 'mod_gain': 7.517478247458339}
# {'bin': 391, 'mod_gain': 1.6935823321458399}
# {'bin': 392, 'mod_gain': 0.7564526206683975}
# {'bin': 393, 'mod_gain': 9.32895200805611}
# {'bin': 394, 'mod_gain': 3.8980207894537644}
# {'bin': 395, 'mod_gain': 0.9383531956033697}
# {'bin': 396, 'mod_gain': 6.864550078923518}
# {'bin': 397, 'mod_gain': 4.7543033942018464}
# {'bin': 398, 'mod_gain': 7.09396568001878}
# {'bin': 399, 'mod_gain': 1.9046368200011377}
# {'bin': 400, 'mod_gain': 9.8905471743688}
# {'bin': 401, 'mod_gain': 7.071741841160495}
# {'bin': 402, 'mod_gain': 9.317673845751015}
# {'bin': 403, 'mod_gain': 4.030052798193032}
# {'bin': 404, 'mod_gain': 4.305810757711509}
# {'bin': 405, 'mod_gain': 1.0098627076238398}
# {'bin': 406, 'mod_gain': 2.1161883618828714}
# {'bin': 407, 'mod_gain': 4.109401063221252}
# {'bin': 408, 'mod_gain': 3.1831474076977995}
# {'bin': 409, 'mod_gain': 2.474138542402524}
# {'bin': 410, 'mod_gain': 4.173091927969761}
# {'bin': 411, 'mod_gain': 6.6451043608717395}
# {'bin': 412, 'mod_gain': 1.9839149316298699}
# {'bin': 413, 'mod_gain': 6.981741538392385}
# {'bin': 414, 'mod_gain': 1.8304676751545723}
# {'bin': 415, 'mod_gain': 6.649744974750682}
# {'bin': 416, 'mod_gain': 3.1211129908041615}
# {'bin': 417, 'mod_gain': 2.2740831214251447}
# {'bin': 418, 'mod_gain': 6.541692446829902}
# {'bin': 419, 'mod_gain': 5.041478315570683}
# {'bin': 420, 'mod_gain': 4.981944345967168}
# {'bin': 421, 'mod_gain': 2.201622040125822}
# {'bin': 422, 'mod_gain': 2.1036471130505916}
# {'bin': 423, 'mod_gain': 1.7370180947512448}
# {'bin': 424, 'mod_gain': 6.066813753961979}
# {'bin': 425, 'mod_gain': 9.828474882024828}
# {'bin': 426, 'mod_gain': 6.499799046702211}
# {'bin': 427, 'mod_gain': 5.356630992669812}
# {'bin': 428, 'mod_gain': 0.5751828842213591}
# {'bin': 429, 'mod_gain': 5.8688806707815635}
# {'bin': 430, 'mod_gain': 5.997102108242322}
# {'bin': 431, 'mod_gain': 2.0898253075972164}
# {'bin': 432, 'mod_gain': 6.039746054445528}
# {'bin': 433, 'mod_gain': 4.434381275668531}
# {'bin': 434, 'mod_gain': 1.152962661389546}
# {'bin': 435, 'mod_gain': 7.800908641079469}
# {'bin': 436, 'mod_gain': 2.1434104212718696}
# {'bin': 437, 'mod_gain': 6.9239047935890055}
# {'bin': 438, 'mod_gain': 6.626833490374295}
# {'bin': 439, 'mod_gain': 3.161002593472977}
# {'bin': 440, 'mod_gain': 5.739370211548433}
# {'bin': 441, 'mod_gain': 0.2065608734207769}
# {'bin': 442, 'mod_gain': 8.875308615829761}
# {'bin': 443, 'mod_gain': 0.11666854472409449}
# {'bin': 444, 'mod_gain': 4.378215468510797}
# {'bin': 445, 'mod_gain': 9.69827379525718}
# {'bin': 446, 'mod_gain': 9.856331162015113}
# {'bin': 447, 'mod_gain': 5.842908508489182}
# {'bin': 448, 'mod_gain': 8.028141183738395}
# {'bin': 449, 'mod_gain': 8.848357935003351}
# {'bin': 450, 'mod_gain': 6.6281677549633}
# {'bin': 451, 'mod_gain': 4.146985358727971}
# {'bin': 452, 'mod_gain': 0.7595549595120299}
# {'bin': 453, 'mod_gain': 0.8918030967100232}
# {'bin': 454, 'mod_gain': 1.8107274234062143}
# {'bin': 455, 'mod_gain': 6.077253032706684}
# {'bin': 456, 'mod_gain': 4.024925923838479}
# {'bin': 457, 'mod_gain': 0.7558082856015702}
# {'bin': 458, 'mod_gain': 0.15385022976618146}
# {'bin': 459, 'mod_gain': 4.80187479013522}
# {'bin': 460, 'mod_gain': 2.8155296276074915}
# {'bin': 461, 'mod_gain': 0.6894077839753121}
# {'bin': 462, 'mod_gain': 0.5723051075199415}
# {'bin': 463, 'mod_gain': 2.435409443986485}
# {'bin': 464, 'mod_gain': 6.481440653613745}
# {'bin': 465, 'mod_gain': 8.221368982846299}
# {'bin': 466, 'mod_gain': 4.929384049521074}
# {'bin': 467, 'mod_gain': 3.354267139237205}
# {'bin': 468, 'mod_gain': 8.348960747585618}
# {'bin': 469, 'mod_gain': 1.8091251918889617}
# {'bin': 470, 'mod_gain': 5.108549210786451}
# {'bin': 471, 'mod_gain': 9.32163235948217}
# {'bin': 472, 'mod_gain': 1.5745850795463878}
# {'bin': 473, 'mod_gain': 6.546085367688528}
# {'bin': 474, 'mod_gain': 0.9359056224773643}
# {'bin': 475, 'mod_gain': 8.663513902828784}
# {'bin': 476, 'mod_gain': 5.798531488765256}
# {'bin': 477, 'mod_gain': 0.5097908516821648}
# {'bin': 478, 'mod_gain': 9.499323767920332}
# {'bin': 479, 'mod_gain': 1.2475989513556673}
# {'bin': 480, 'mod_gain': 6.875226347536931}
# {'bin': 481, 'mod_gain': 9.884789670129738}
# {'bin': 482, 'mod_gain': 1.628989337301896}
# {'bin': 483, 'mod_gain': 8.54923656371054}
# {'bin': 484, 'mod_gain': 2.755401299590509}
# {'bin': 485, 'mod_gain': 4.7429470138953445}
# {'bin': 486, 'mod_gain': 4.951008079929528}
# {'bin': 487, 'mod_gain': 4.782576969175267}
# {'bin': 488, 'mod_gain': 5.251736697359737}
# {'bin': 489, 'mod_gain': 2.961422776152387}
# {'bin': 490, 'mod_gain': 9.3353600619359}
# {'bin': 491, 'mod_gain': 9.054384509255755}
# {'bin': 492, 'mod_gain': 0.712620575023234}
# {'bin': 493, 'mod_gain': 9.214729571254317}
# {'bin': 494, 'mod_gain': 3.1637440233146186}
# {'bin': 495, 'mod_gain': 3.7611409073058466}
# {'bin': 496, 'mod_gain': 0.7570894670166473}
# {'bin': 497, 'mod_gain': 9.059137428323606}
# {'bin': 498, 'mod_gain': 3.6775676346633333}
# {'bin': 499, 'mod_gain': 1.4440650362469432}
# {'bin': 500, 'mod_gain': 2.029850986412222}
# {'bin': 501, 'mod_gain': 1.779132669839516}
# {'bin': 502, 'mod_gain': 1.2633642796639888}
# {'bin': 503, 'mod_gain': 0.7647898649379414}
# {'bin': 504, 'mod_gain': 9.818845947797117}
# {'bin': 505, 'mod_gain': 6.337421724224496}
# {'bin': 506, 'mod_gain': 4.093893215056358}
# {'bin': 507, 'mod_gain': 4.065299343531662}
# {'bin': 508, 'mod_gain': 1.608650898735161}
# {'bin': 509, 'mod_gain': 6.234856788140695}
# {'bin': 510, 'mod_gain': 0.6554886673679794}
# {'bin': 511, 'mod_gain': 2.1674288438128118}
# {'bin': 512, 'mod_gain': 7.300014932718075}
# {'bin': 513, 'mod_gain': 2.881800858876875}
# {'bin': 514, 'mod_gain': 9.895931752937564}
# {'bin': 515, 'mod_gain': 3.4522562986308705}
# {'bin': 516, 'mod_gain': 0.867131160983512}
# {'bin': 517, 'mod_gain': 6.705688052574377}
# {'bin': 518, 'mod_gain': 2.3011448187947514}
# {'bin': 519, 'mod_gain': 5.817074769507412}
# {'bin': 520, 'mod_gain': 7.733867071944589}
# {'bin': 521, 'mod_gain': 9.927015937543448}
# {'bin': 522, 'mod_gain': 8.64762691844312}
# {'bin': 523, 'mod_gain': 0.012512223651972576}
# {'bin': 524, 'mod_gain': 2.0581407296641316}
# {'bin': 525, 'mod_gain': 7.669628449229958}
# {'bin': 526, 'mod_gain': 5.862928569881305}
# {'bin': 527, 'mod_gain': 0.3013801464876231}
# {'bin': 528, 'mod_gain': 2.180471564239943}
# {'bin': 529, 'mod_gain': 3.0856053388878033}
# {'bin': 530, 'mod_gain': 1.1973245561655366}
# {'bin': 531, 'mod_gain': 9.58025370172104}
# {'bin': 532, 'mod_gain': 9.452845031974002}
# {'bin': 533, 'mod_gain': 8.281701982910208}
# {'bin': 534, 'mod_gain': 4.467500947653566}
# {'bin': 535, 'mod_gain': 9.025061941413847}
# {'bin': 536, 'mod_gain': 4.8943629201298675}
# {'bin': 537, 'mod_gain': 5.293255024914892}
# {'bin': 538, 'mod_gain': 7.308591079255251}
# {'bin': 539, 'mod_gain': 4.7389733104362195}
# {'bin': 540, 'mod_gain': 9.882257376170907}
# {'bin': 541, 'mod_gain': 1.1862427734807524}
# {'bin': 542, 'mod_gain': 6.4988529709498986}
# {'bin': 543, 'mod_gain': 7.647307642273985}
# {'bin': 544, 'mod_gain': 0.8305912569084017}
# {'bin': 545, 'mod_gain': 4.9061383566680465}
# {'bin': 546, 'mod_gain': 3.52640494884777}
# {'bin': 547, 'mod_gain': 7.99540245537755}
# {'bin': 548, 'mod_gain': 3.732399010645878}
# {'bin': 549, 'mod_gain': 9.988910332558701}
# {'bin': 550, 'mod_gain': 4.07259332393934}
# {'bin': 551, 'mod_gain': 9.299933121820478}
# {'bin': 552, 'mod_gain': 3.2917387001485485}
# {'bin': 553, 'mod_gain': 1.3609699941471387}
# {'bin': 554, 'mod_gain': 5.248153409316727}
# {'bin': 555, 'mod_gain': 2.234108614269145}
# {'bin': 556, 'mod_gain': 9.596493250505214}
# {'bin': 557, 'mod_gain': 2.8112104561285314}
# {'bin': 558, 'mod_gain': 1.4190389833469874}
# {'bin': 559, 'mod_gain': 7.675665733537002}
# {'bin': 560, 'mod_gain': 0.16400678362589294}
# {'bin': 561, 'mod_gain': 6.31412341429148}
# {'bin': 562, 'mod_gain': 1.5467067781164334}
# {'bin': 563, 'mod_gain': 4.19189678900498}
# {'bin': 564, 'mod_gain': 2.4887003190905}
# {'bin': 565, 'mod_gain': 1.740129621647759}
# {'bin': 566, 'mod_gain': 9.12408013846015}
# {'bin': 567, 'mod_gain': 6.163652711119475}
# {'bin': 568, 'mod_gain': 6.366603822091422}
# {'bin': 569, 'mod_gain': 0.9071447572416136}
# {'bin': 570, 'mod_gain': 7.718756045050791}
# {'bin': 571, 'mod_gain': 3.9132013512377153}
# {'bin': 572, 'mod_gain': 1.6442829227307376}
# {'bin': 573, 'mod_gain': 6.939586791897062}
# {'bin': 574, 'mod_gain': 4.094432675703102}
# {'bin': 575, 'mod_gain': 7.2547976780151116}
# {'bin': 576, 'mod_gain': 6.432511590827321}
# {'bin': 577, 'mod_gain': 3.6784845033116964}
# {'bin': 578, 'mod_gain': 2.0025783451251025}
# {'bin': 579, 'mod_gain': 0.22473753856693923}
# {'bin': 580, 'mod_gain': 0.16602140910641827}
# {'bin': 581, 'mod_gain': 3.6175893943306168}
# {'bin': 582, 'mod_gain': 9.298860980387909}
# {'bin': 583, 'mod_gain': 3.1782766973520538}
# {'bin': 584, 'mod_gain': 9.06487573175682}
# {'bin': 585, 'mod_gain': 8.884896246466191}
# {'bin': 586, 'mod_gain': 6.110351862630252}
# {'bin': 587, 'mod_gain': 1.2373886839485249}
# {'bin': 588, 'mod_gain': 2.7359241406691206}
# {'bin': 589, 'mod_gain': 5.718447095933952}
# {'bin': 590, 'mod_gain': 2.3084302660782106}
# {'bin': 591, 'mod_gain': 6.529118197065875}
# {'bin': 592, 'mod_gain': 6.4093769432590175}
# {'bin': 593, 'mod_gain': 9.629725259168444}
# {'bin': 594, 'mod_gain': 7.805861104336527}
# {'bin': 595, 'mod_gain': 1.6064796820480065}
# {'bin': 596, 'mod_gain': 5.715553102131047}
# {'bin': 597, 'mod_gain': 7.245404669412144}
# {'bin': 598, 'mod_gain': 6.145050890110798}
# {'bin': 599, 'mod_gain': 3.6784192992188878}
# {'bin': 600, 'mod_gain': 6.505670664453948}
# {'bin': 601, 'mod_gain': 5.271556458878251}
# {'bin': 602, 'mod_gain': 0.1999809461421631}
# {'bin': 603, 'mod_gain': 2.6784289266789605}
# {'bin': 604, 'mod_gain': 6.31775884621831}
# {'bin': 605, 'mod_gain': 5.784218886839495}
# {'bin': 606, 'mod_gain': 1.714644503291426}
# {'bin': 607, 'mod_gain': 7.168352326714695}
# {'bin': 608, 'mod_gain': 5.827793645487645}
# {'bin': 609, 'mod_gain': 8.261112115205348}
# {'bin': 610, 'mod_gain': 1.302010558400294}
# {'bin': 611, 'mod_gain': 4.428846350801497}
# {'bin': 612, 'mod_gain': 3.5456308926147786}
# {'bin': 613, 'mod_gain': 3.000745246081289}
# {'bin': 614, 'mod_gain': 9.037187487043546}
# {'bin': 615, 'mod_gain': 6.6150934346203325}
# {'bin': 616, 'mod_gain': 7.923675315842783}
# {'bin': 617, 'mod_gain': 5.59974797488405}
# {'bin': 618, 'mod_gain': 0.0019940185504163654}
# {'bin': 619, 'mod_gain': 8.635584607885875}
# {'bin': 620, 'mod_gain': 3.572127579613227}
# {'bin': 621, 'mod_gain': 4.982133402289383}
# {'bin': 622, 'mod_gain': 0.1741266035682043}
# {'bin': 623, 'mod_gain': 6.362229454345767}
# {'bin': 624, 'mod_gain': 0.40808553075526777}
# {'bin': 625, 'mod_gain': 7.60979329201417}
# {'bin': 626, 'mod_gain': 3.5635928073046297}
# {'bin': 627, 'mod_gain': 9.075473099047223}
# {'bin': 628, 'mod_gain': 5.543937565043109}
# {'bin': 629, 'mod_gain': 6.092082334109408}
# {'bin': 630, 'mod_gain': 8.423238754924752}
# {'bin': 631, 'mod_gain': 2.8781456666144587}
# {'bin': 632, 'mod_gain': 4.715520842451809}
# {'bin': 633, 'mod_gain': 1.0714065099187808}
# {'bin': 634, 'mod_gain': 8.660305208120342}
# {'bin': 635, 'mod_gain': 0.3637239295137462}
# {'bin': 636, 'mod_gain': 0.5967463274576079}
# {'bin': 637, 'mod_gain': 0.20194532114063635}
# {'bin': 638, 'mod_gain': 0.2835647311794709}
# {'bin': 639, 'mod_gain': 4.976629310294419}
# {'bin': 640, 'mod_gain': 1.8759270298093544}
# {'bin': 641, 'mod_gain': 5.750847301654927}
# {'bin': 642, 'mod_gain': 5.8632424513389}
# {'bin': 643, 'mod_gain': 7.165341827826255}
# {'bin': 644, 'mod_gain': 4.307944489550715}
# {'bin': 645, 'mod_gain': 4.418941539886702}
# {'bin': 646, 'mod_gain': 6.959338002466771}
# {'bin': 647, 'mod_gain': 9.43281105399145}
# {'bin': 648, 'mod_gain': 8.662693931044632}
# {'bin': 649, 'mod_gain': 7.012110456062896}
# {'bin': 650, 'mod_gain': 2.910094727053467}
# {'bin': 651, 'mod_gain': 3.726936353704554}
# {'bin': 652, 'mod_gain': 2.68669928145008}
# {'bin': 653, 'mod_gain': 4.367783566291056}
# {'bin': 654, 'mod_gain': 5.312675574052187}
# {'bin': 655, 'mod_gain': 6.002297328764779}
# {'bin': 656, 'mod_gain': 6.855966645022659}
# {'bin': 657, 'mod_gain': 7.134021959828094}
# {'bin': 658, 'mod_gain': 0.40741600514554777}
# {'bin': 659, 'mod_gain': 8.601613476411426}
# {'bin': 660, 'mod_gain': 1.3368828941405086}
# {'bin': 661, 'mod_gain': 1.4367623479867542}
# {'bin': 662, 'mod_gain': 6.209327160107123}
# {'bin': 663, 'mod_gain': 3.700163943052389}
# {'bin': 664, 'mod_gain': 1.7121420128190545}
# {'bin': 665, 'mod_gain': 7.934056979910818}
# {'bin': 666, 'mod_gain': 3.8971043732421617}
# {'bin': 667, 'mod_gain': 4.668236769042977}
# {'bin': 668, 'mod_gain': 8.670008563480756}
# {'bin': 669, 'mod_gain': 1.0207979880819895}
# {'bin': 670, 'mod_gain': 1.8841556797648706}
# {'bin': 671, 'mod_gain': 6.3538245576044075}
# {'bin': 672, 'mod_gain': 9.173999368641773}
# {'bin': 673, 'mod_gain': 7.878651202766705}
# {'bin': 674, 'mod_gain': 4.230245592960793}
# {'bin': 675, 'mod_gain': 4.654971275962808}
# {'bin': 676, 'mod_gain': 1.7934264821519275}
# {'bin': 677, 'mod_gain': 9.286414363881565}
# {'bin': 678, 'mod_gain': 6.634511224507676}
# {'bin': 679, 'mod_gain': 7.274123661219542}
# {'bin': 680, 'mod_gain': 5.208722918479794}
# {'bin': 681, 'mod_gain': 6.496031700832699}
# {'bin': 682, 'mod_gain': 2.115735237768109}
# {'bin': 683, 'mod_gain': 3.438580405468973}
# {'bin': 684, 'mod_gain': 7.9846372629980475}
# {'bin': 685, 'mod_gain': 9.76548123014973}
# {'bin': 686, 'mod_gain': 4.850007135924691}
# {'bin': 687, 'mod_gain': 6.563621003099193}
# {'bin': 688, 'mod_gain': 1.076045601969603}
# {'bin': 689, 'mod_gain': 5.755017231620812}
# {'bin': 690, 'mod_gain': 4.378713702523644}
# {'bin': 691, 'mod_gain': 7.072281975711114}
# {'bin': 692, 'mod_gain': 6.406637701874769}
# {'bin': 693, 'mod_gain': 7.896480765341409}
# {'bin': 694, 'mod_gain': 6.611211994677753}
# {'bin': 695, 'mod_gain': 8.595474470190524}
# {'bin': 696, 'mod_gain': 3.3818033951964024}
# {'bin': 697, 'mod_gain': 2.9117821787272735}
# {'bin': 698, 'mod_gain': 9.618893331596908}
# {'bin': 699, 'mod_gain': 2.5978560059075537}
# {'bin': 700, 'mod_gain': 0.5534279802119046}
# {'bin': 701, 'mod_gain': 0.3821175500251228}
# {'bin': 702, 'mod_gain': 5.781870372031413}
# {'bin': 703, 'mod_gain': 8.647634350971797}
# {'bin': 704, 'mod_gain': 4.350281021240176}
# {'bin': 705, 'mod_gain': 8.763877035951413}
# {'bin': 706, 'mod_gain': 8.681961396922475}
# {'bin': 707, 'mod_gain': 7.189358051608302}
# {'bin': 708, 'mod_gain': 4.144667414657861}
# {'bin': 709, 'mod_gain': 7.385391386279826}
# {'bin': 710, 'mod_gain': 3.9456538154780674}
# {'bin': 711, 'mod_gain': 4.9216490351918925}
# {'bin': 712, 'mod_gain': 9.86308172045839}
# {'bin': 713, 'mod_gain': 8.581434643224629}
# {'bin': 714, 'mod_gain': 4.169415938737984}
# {'bin': 715, 'mod_gain': 3.973048332668637}
# {'bin': 716, 'mod_gain': 1.310575392924055}
# {'bin': 717, 'mod_gain': 8.300793292605475}
# {'bin': 718, 'mod_gain': 8.114002859129226}
# {'bin': 719, 'mod_gain': 0.3165103878668851}
# {'bin': 720, 'mod_gain': 1.0440473480469936}
# {'bin': 721, 'mod_gain': 6.556438302662553}
# {'bin': 722, 'mod_gain': 2.506942902851085}
# {'bin': 723, 'mod_gain': 5.590180442040697}
# {'bin': 724, 'mod_gain': 2.0416259118385094}
# {'bin': 725, 'mod_gain': 4.913949668640079}
# {'bin': 726, 'mod_gain': 8.579725943099456}
# {'bin': 727, 'mod_gain': 3.2495849755162887}
# {'bin': 728, 'mod_gain': 8.771120995800366}
# {'bin': 729, 'mod_gain': 3.1946639434453115}
# {'bin': 730, 'mod_gain': 3.243045360326271}
# {'bin': 731, 'mod_gain': 8.244262301052505}
# {'bin': 732, 'mod_gain': 2.1866393488474967}
# {'bin': 733, 'mod_gain': 3.7419594898696906}
# {'bin': 734, 'mod_gain': 0.9192422061918981}
# {'bin': 735, 'mod_gain': 1.9805765081881432}
# {'bin': 736, 'mod_gain': 4.474862106344926}
# {'bin': 737, 'mod_gain': 8.736259743718659}
# {'bin': 738, 'mod_gain': 6.571410951715537}
# {'bin': 739, 'mod_gain': 3.4195661555034174}
# {'bin': 740, 'mod_gain': 0.6247967139096733}
# {'bin': 741, 'mod_gain': 7.738680650282577}
# {'bin': 742, 'mod_gain': 7.715015651628121}
# {'bin': 743, 'mod_gain': 8.97479755469638}
# {'bin': 744, 'mod_gain': 8.523198539448886}
# {'bin': 745, 'mod_gain': 5.882186604691432}
# {'bin': 746, 'mod_gain': 4.108407894287884}
# {'bin': 747, 'mod_gain': 4.814747989962087}
# {'bin': 748, 'mod_gain': 9.699632420640517}
# {'bin': 749, 'mod_gain': 8.989211034965287}
# {'bin': 750, 'mod_gain': 3.5286869916174943}
# {'bin': 751, 'mod_gain': 9.540958260750049}
# {'bin': 752, 'mod_gain': 6.795508487805453}
# {'bin': 753, 'mod_gain': 3.4954943157535046}
# {'bin': 754, 'mod_gain': 3.8858734993902955}
# {'bin': 755, 'mod_gain': 3.64624647201821}
# {'bin': 756, 'mod_gain': 8.007643969970369}
# {'bin': 757, 'mod_gain': 0.706873145207445}
# {'bin': 758, 'mod_gain': 1.1999855643058854}
# {'bin': 759, 'mod_gain': 5.598444808087814}
# {'bin': 760, 'mod_gain': 8.015675357961427}
# {'bin': 761, 'mod_gain': 0.9546537235372954}
# {'bin': 762, 'mod_gain': 8.487067221195396}
# {'bin': 763, 'mod_gain': 8.768849159213271}
# {'bin': 764, 'mod_gain': 6.130559247721568}
# {'bin': 765, 'mod_gain': 6.292466983507625}
# {'bin': 766, 'mod_gain': 5.275846311469118}
# {'bin': 767, 'mod_gain': 7.951629995604731}
# {'bin': 768, 'mod_gain': 6.935998093034197}
# {'bin': 769, 'mod_gain': 8.299773170214241}
# {'bin': 770, 'mod_gain': 7.791665370494629}
# {'bin': 771, 'mod_gain': 5.130296303223934}
# {'bin': 772, 'mod_gain': 8.049267945010271}
# {'bin': 773, 'mod_gain': 8.311911434745333}
# {'bin': 774, 'mod_gain': 6.072654479622258}
# {'bin': 775, 'mod_gain': 0.16813285389659205}
# {'bin': 776, 'mod_gain': 8.169963634962556}
# {'bin': 777, 'mod_gain': 6.496683663928876}
# {'bin': 778, 'mod_gain': 1.4145573728596883}
# {'bin': 779, 'mod_gain': 0.7004575344185016}
# {'bin': 780, 'mod_gain': 0.7778603505076764}
# {'bin': 781, 'mod_gain': 0.11043572077271135}
# {'bin': 782, 'mod_gain': 6.369021470889036}
# {'bin': 783, 'mod_gain': 1.0585971119406046}
# {'bin': 784, 'mod_gain': 0.17595092044217053}
# {'bin': 785, 'mod_gain': 8.803657213615445}
# {'bin': 786, 'mod_gain': 3.2501524547267033}
# {'bin': 787, 'mod_gain': 6.56286455853225}
# {'bin': 788, 'mod_gain': 5.996191175823418}
# {'bin': 789, 'mod_gain': 0.5071294119533909}
# {'bin': 790, 'mod_gain': 5.7696475397122695}
# {'bin': 791, 'mod_gain': 4.340300591845559}
# {'bin': 792, 'mod_gain': 2.738495366538568}
# {'bin': 793, 'mod_gain': 2.9817567197619566}
# {'bin': 794, 'mod_gain': 9.501911864391204}
# {'bin': 795, 'mod_gain': 7.693665473323152}
# {'bin': 796, 'mod_gain': 3.8961172886210083}
# {'bin': 797, 'mod_gain': 3.2460145825988973}
# {'bin': 798, 'mod_gain': 7.578079966876574}
# {'bin': 799, 'mod_gain': 3.5741090208515667}
# {'bin': 800, 'mod_gain': 0.05374824507310305}
# {'bin': 801, 'mod_gain': 9.299560717296405}
# {'bin': 802, 'mod_gain': 9.017562894338099}
# {'bin': 803, 'mod_gain': 6.262388134438512}
# {'bin': 804, 'mod_gain': 9.667522994886866}
# {'bin': 805, 'mod_gain': 6.3041200711961585}
# {'bin': 806, 'mod_gain': 2.8474919305225854}
# {'bin': 807, 'mod_gain': 5.084648296549959}
# {'bin': 808, 'mod_gain': 5.475878881191244}
# {'bin': 809, 'mod_gain': 9.271657053625127}
# {'bin': 810, 'mod_gain': 4.496989447081362}
# {'bin': 811, 'mod_gain': 0.3272631825356975}
# {'bin': 812, 'mod_gain': 9.738479041445256}
# {'bin': 813, 'mod_gain': 3.663694374126173}
# {'bin': 814, 'mod_gain': 9.897196824204956}
# {'bin': 815, 'mod_gain': 8.570359496808248}
# {'bin': 816, 'mod_gain': 0.8929633439093076}
# {'bin': 817, 'mod_gain': 4.5627968107301955}
# {'bin': 818, 'mod_gain': 8.47925892613928}
# {'bin': 819, 'mod_gain': 7.30520714638156}
# {'bin': 820, 'mod_gain': 9.402225340147174}
# {'bin': 821, 'mod_gain': 5.312007873885577}
# {'bin': 822, 'mod_gain': 6.68814876504978}
# {'bin': 823, 'mod_gain': 7.037590759692368}
# {'bin': 824, 'mod_gain': 8.483206463116751}
# {'bin': 825, 'mod_gain': 6.481701832225195}
# {'bin': 826, 'mod_gain': 7.732143667310265}
# {'bin': 827, 'mod_gain': 2.2257140902555017}
# {'bin': 828, 'mod_gain': 5.976613402714806}
# {'bin': 829, 'mod_gain': 9.053937129558959}
# {'bin': 830, 'mod_gain': 9.115029513699932}
# {'bin': 831, 'mod_gain': 0.9942024066610389}
# {'bin': 832, 'mod_gain': 7.518538040047025}
# {'bin': 833, 'mod_gain': 8.631572988628701}
# {'bin': 834, 'mod_gain': 3.8499874478049523}
# {'bin': 835, 'mod_gain': 3.6283059296530693}
# {'bin': 836, 'mod_gain': 2.5548447451980163}
# {'bin': 837, 'mod_gain': 1.223101882570361}
# {'bin': 838, 'mod_gain': 3.632752971691724}
# {'bin': 839, 'mod_gain': 6.0450590435692515}
# {'bin': 840, 'mod_gain': 5.553981729872392}
# {'bin': 841, 'mod_gain': 9.699331291292525}
# {'bin': 842, 'mod_gain': 0.3482946549065691}
# {'bin': 843, 'mod_gain': 4.0974543971692325}
# {'bin': 844, 'mod_gain': 2.5188761597220544}
# {'bin': 845, 'mod_gain': 0.3099454495733478}
# {'bin': 846, 'mod_gain': 4.502600636215119}
# {'bin': 847, 'mod_gain': 5.031793365355752}
# {'bin': 848, 'mod_gain': 8.884322673735225}
# {'bin': 849, 'mod_gain': 7.580563586042471}
# {'bin': 850, 'mod_gain': 4.454435301366917}
# {'bin': 851, 'mod_gain': 5.274072619914718}
# {'bin': 852, 'mod_gain': 4.0452575928820975}
# {'bin': 853, 'mod_gain': 7.354103935153402}
# {'bin': 854, 'mod_gain': 1.9663152552163776}
# {'bin': 855, 'mod_gain': 8.52026889226643}
# {'bin': 856, 'mod_gain': 7.936820784742407}
# {'bin': 857, 'mod_gain': 2.557286583435844}
# {'bin': 858, 'mod_gain': 1.6707413092794454}
# {'bin': 859, 'mod_gain': 1.9217713555918359}
# {'bin': 860, 'mod_gain': 5.384097804514091}
# {'bin': 861, 'mod_gain': 3.9893997959880467}
# {'bin': 862, 'mod_gain': 4.454236346098062}
# {'bin': 863, 'mod_gain': 1.878644103598207}
# {'bin': 864, 'mod_gain': 5.618096317418777}
# {'bin': 865, 'mod_gain': 4.7460801063102265}
# {'bin': 866, 'mod_gain': 8.491987577910248}
# {'bin': 867, 'mod_gain': 2.163875289505844}
# {'bin': 868, 'mod_gain': 9.408954754329974}
# {'bin': 869, 'mod_gain': 5.437408235270981}
# {'bin': 870, 'mod_gain': 7.436211406437206}
# {'bin': 871, 'mod_gain': 7.646018406952163}
# {'bin': 872, 'mod_gain': 4.867302052818362}
# {'bin': 873, 'mod_gain': 8.199240385597081}
# {'bin': 874, 'mod_gain': 9.17978108958078}
# {'bin': 875, 'mod_gain': 6.7258164981061554}
# {'bin': 876, 'mod_gain': 9.069321747584262}
# {'bin': 877, 'mod_gain': 0.4510794286775499}
# {'bin': 878, 'mod_gain': 6.924305374544282}
# {'bin': 879, 'mod_gain': 9.472867563788629}
# {'bin': 880, 'mod_gain': 0.5021796607489104}
# {'bin': 881, 'mod_gain': 0.08142783932952313}
# {'bin': 882, 'mod_gain': 2.2252654440094934}
# {'bin': 883, 'mod_gain': 1.808373795651469}
# {'bin': 884, 'mod_gain': 3.436192057897993}
# {'bin': 885, 'mod_gain': 5.033807272542282}
# {'bin': 886, 'mod_gain': 4.7880380547480605}
# {'bin': 887, 'mod_gain': 7.137968850661874}
# {'bin': 888, 'mod_gain': 3.1573521600615297}
# {'bin': 889, 'mod_gain': 1.2379398085938065}
# {'bin': 890, 'mod_gain': 2.102430636039332}
# {'bin': 891, 'mod_gain': 0.46957227524720424}
# {'bin': 892, 'mod_gain': 7.244594706525761}
# {'bin': 893, 'mod_gain': 5.450630272298885}
# {'bin': 894, 'mod_gain': 0.6815102079097091}
# {'bin': 895, 'mod_gain': 2.6705817234659692}
# {'bin': 896, 'mod_gain': 3.9189432852069164}
# {'bin': 897, 'mod_gain': 1.4513077257292584}
# {'bin': 898, 'mod_gain': 9.189573343980818}
# {'bin': 899, 'mod_gain': 2.758674392204071}
# {'bin': 900, 'mod_gain': 0.9241957813499413}
# {'bin': 901, 'mod_gain': 4.861498304048309}
# {'bin': 902, 'mod_gain': 8.859268237179448}
# {'bin': 903, 'mod_gain': 8.184775260720626}
# {'bin': 904, 'mod_gain': 9.325687531647443}
# {'bin': 905, 'mod_gain': 7.312307719017765}
# {'bin': 906, 'mod_gain': 1.6417937491954204}
# {'bin': 907, 'mod_gain': 8.64668351099428}
# {'bin': 908, 'mod_gain': 7.871906426860381}
# {'bin': 909, 'mod_gain': 1.592107079026246}
# {'bin': 910, 'mod_gain': 8.162225269624683}
# {'bin': 911, 'mod_gain': 5.774643055596924}
# {'bin': 912, 'mod_gain': 6.715411989572347}
# {'bin': 913, 'mod_gain': 1.5858124268048424}
# {'bin': 914, 'mod_gain': 3.3953123890006}
# {'bin': 915, 'mod_gain': 3.5362493452230357}
# {'bin': 916, 'mod_gain': 4.427755845298677}
# {'bin': 917, 'mod_gain': 3.387011638477242}
# {'bin': 918, 'mod_gain': 7.237055524998168}
# {'bin': 919, 'mod_gain': 4.272814911585213}
# {'bin': 920, 'mod_gain': 8.576602912482867}
# {'bin': 921, 'mod_gain': 7.270554624960168}
# {'bin': 922, 'mod_gain': 8.581511157715703}
# {'bin': 923, 'mod_gain': 4.247045301179507}
# {'bin': 924, 'mod_gain': 5.990613676588304}
# {'bin': 925, 'mod_gain': 0.12640018160322342}
# {'bin': 926, 'mod_gain': 8.794952311171055}
# {'bin': 927, 'mod_gain': 8.078122712101138}
# {'bin': 928, 'mod_gain': 3.2282368638237866}
# {'bin': 929, 'mod_gain': 9.919632284251128}
# {'bin': 930, 'mod_gain': 0.25243810121770793}
# {'bin': 931, 'mod_gain': 8.59463813641803}
# {'bin': 932, 'mod_gain': 3.019488379851004}
# {'bin': 933, 'mod_gain': 3.6234724007932884}
# {'bin': 934, 'mod_gain': 3.5288043206579256}
# {'bin': 935, 'mod_gain': 6.159082245895959}
# {'bin': 936, 'mod_gain': 1.7669216569282087}
# {'bin': 937, 'mod_gain': 6.369496012911521}
# {'bin': 938, 'mod_gain': 6.52686117770971}
# {'bin': 939, 'mod_gain': 1.7299899064618929}
# {'bin': 940, 'mod_gain': 6.791445702325323}
# {'bin': 941, 'mod_gain': 1.073849594883941}
# {'bin': 942, 'mod_gain': 5.910981436420984}
# {'bin': 943, 'mod_gain': 6.470466835656927}
# {'bin': 944, 'mod_gain': 6.484241233987287}
# {'bin': 945, 'mod_gain': 0.6186226865207289}
# {'bin': 946, 'mod_gain': 4.786529904492173}
# {'bin': 947, 'mod_gain': 3.1019749209740786}
# {'bin': 948, 'mod_gain': 1.6995543289458126}
# {'bin': 949, 'mod_gain': 6.32797223066842}
# {'bin': 950, 'mod_gain': 5.603205195050771}
# {'bin': 951, 'mod_gain': 1.3914129822385468}
# {'bin': 952, 'mod_gain': 2.4112867563035225}
# {'bin': 953, 'mod_gain': 5.349838453159209}
# {'bin': 954, 'mod_gain': 4.22894385159397}
# {'bin': 955, 'mod_gain': 3.5682747832423525}
# {'bin': 956, 'mod_gain': 7.0444193444559495}
# {'bin': 957, 'mod_gain': 1.3159639932810985}
# {'bin': 958, 'mod_gain': 4.446306105339726}
# {'bin': 959, 'mod_gain': 7.453804438448007}
# {'bin': 960, 'mod_gain': 6.2561852236950415}
# {'bin': 961, 'mod_gain': 0.2673739295032196}
# {'bin': 962, 'mod_gain': 7.781749413488153}
# {'bin': 963, 'mod_gain': 7.876156869112178}
# {'bin': 964, 'mod_gain': 7.595964245487047}
# {'bin': 965, 'mod_gain': 1.7688557473270905}
# {'bin': 966, 'mod_gain': 6.159136314989718}
# {'bin': 967, 'mod_gain': 6.118171860426635}
# {'bin': 968, 'mod_gain': 6.441964681637331}
# {'bin': 969, 'mod_gain': 8.896971091994207}
# {'bin': 970, 'mod_gain': 6.712763930255329}
# {'bin': 971, 'mod_gain': 2.7664762105148775}
# {'bin': 972, 'mod_gain': 2.3617925376819517}
# {'bin': 973, 'mod_gain': 8.015922699783184}
# {'bin': 974, 'mod_gain': 9.905446881788059}
# {'bin': 975, 'mod_gain': 9.419089597812999}
# {'bin': 976, 'mod_gain': 4.963263558081033}
# {'bin': 977, 'mod_gain': 4.999912794102267}
# {'bin': 978, 'mod_gain': 0.048303968904840344}
# {'bin': 979, 'mod_gain': 6.150210817673635}
# {'bin': 980, 'mod_gain': 4.529366032956002}
# {'bin': 981, 'mod_gain': 2.9479405091703126}
# {'bin': 982, 'mod_gain': 8.123450592599278}
# {'bin': 983, 'mod_gain': 1.1146990704747317}
# {'bin': 984, 'mod_gain': 6.006233875758359}
# {'bin': 985, 'mod_gain': 2.9257075414130904}
# {'bin': 986, 'mod_gain': 9.308754298506244}
# {'bin': 987, 'mod_gain': 8.154144634647224}
# {'bin': 988, 'mod_gain': 4.420053445307857}
# {'bin': 989, 'mod_gain': 6.681731684804598}
# {'bin': 990, 'mod_gain': 6.102544910173519}
# {'bin': 991, 'mod_gain': 0.6798112588564542}
# {'bin': 992, 'mod_gain': 2.234355712198445}
# {'bin': 993, 'mod_gain': 0.5375681652063868}
# {'bin': 994, 'mod_gain': 7.4656006114619045}
# {'bin': 995, 'mod_gain': 7.6921852615589845}
# {'bin': 996, 'mod_gain': 5.779806216029146}
# {'bin': 997, 'mod_gain': 9.661047328579832}
# {'bin': 998, 'mod_gain': 7.325475056767527}
# {'bin': 999, 'mod_gain': 7.6872129613774245}
# {'bin': 1000, 'mod_gain': 4.297359386550344}
# {'bin': 1001, 'mod_gain': 0.5744606017006249}
# {'bin': 1002, 'mod_gain': 3.598675504851178}
# {'bin': 1003, 'mod_gain': 3.3686081311244753}
# {'bin': 1004, 'mod_gain': 0.8619312124021472}
# {'bin': 1005, 'mod_gain': 1.9665475168302493}
# {'bin': 1006, 'mod_gain': 9.05492657992464}
# {'bin': 1007, 'mod_gain': 8.747271931306006}
# {'bin': 1008, 'mod_gain': 1.4855621007816244}
# {'bin': 1009, 'mod_gain': 1.642270561614152}
# {'bin': 1010, 'mod_gain': 8.15568121870846}
# {'bin': 1011, 'mod_gain': 1.7040464097294505}
# {'bin': 1012, 'mod_gain': 0.2711636546518359}
# {'bin': 1013, 'mod_gain': 8.551092638313456}
# {'bin': 1014, 'mod_gain': 6.503976095111401}
# {'bin': 1015, 'mod_gain': 9.268253944684695}
# {'bin': 1016, 'mod_gain': 9.45140559939047}
# {'bin': 1017, 'mod_gain': 0.09316591035554933}
# {'bin': 1018, 'mod_gain': 8.02079489788835}
# {'bin': 1019, 'mod_gain': 3.1562763777009106}
# {'bin': 1020, 'mod_gain': 7.442889989722319}
# {'bin': 1021, 'mod_gain': 5.910096128686476}
# {'bin': 1022, 'mod_gain': 0.6802885078625465}
# {'bin': 1023, 'mod_gain': 3.0466078405601174}
# {'bin': 1024, 'mod_gain': 0.4145618752726077}
# {'bin': 0, 'shift': 0.0}
# {'bin': 1, 'shift': 0.75}
# {'bin': 2, 'shift': 0.75}
# {'bin': 3, 'shift': 0.0}
# {'bin': 4, 'shift': 0.5}
# {'bin': 5, 'shift': 0.5}
# {'bin': 6, 'shift': 0.75}
# {'bin': 7, 'shift': 0.25}
# {'bin': 8, 'shift': 0.25}
# {'bin': 9, 'shift': 0.25}
# {'bin': 10, 'shift': 0.0}
# {'bin': 11, 'shift': 0.5}
# {'bin': 12, 'shift': 0.75}
# {'bin': 13, 'shift': 0.25}
# {'bin': 14, 'shift': 0.25}
# {'bin': 15, 'shift': 0.25}
# {'bin': 16, 'shift': 0.5}
# {'bin': 17, 'shift': 0.0}
# {'bin': 18, 'shift': 0.75}
# {'bin': 19, 'shift': 0.25}
# {'bin': 20, 'shift': 0.25}
# {'bin': 21, 'shift': 0.25}
# {'bin': 22, 'shift': 0.75}
# {'bin': 23, 'shift': 0.5}
# {'bin': 24, 'shift': 0.5}
# {'bin': 25, 'shift': 0.75}
# {'bin': 26, 'shift': 0.5}
# {'bin': 27, 'shift': 0.0}
# {'bin': 28, 'shift': 0.75}
# {'bin': 29, 'shift': 0.25}
# {'bin': 30, 'shift': 0.25}
# {'bin': 31, 'shift': 0.25}
# {'bin': 32, 'shift': 0.25}
# {'bin': 33, 'shift': 0.0}
# {'bin': 34, 'shift': 0.75}
# {'bin': 35, 'shift': 0.0}
# {'bin': 36, 'shift': 0.0}
# {'bin': 37, 'shift': 0.5}
# {'bin': 38, 'shift': 0.0}
# {'bin': 39, 'shift': 0.75}
# {'bin': 40, 'shift': 0.0}
# {'bin': 41, 'shift': 0.75}
# {'bin': 42, 'shift': 0.0}
# {'bin': 43, 'shift': 0.75}
# {'bin': 44, 'shift': 0.0}
# {'bin': 45, 'shift': 0.25}
# {'bin': 46, 'shift': 0.0}
# {'bin': 47, 'shift': 0.0}
# {'bin': 48, 'shift': 0.25}
# {'bin': 49, 'shift': 0.0}
# {'bin': 50, 'shift': 0.5}
# {'bin': 51, 'shift': 0.75}
# {'bin': 52, 'shift': 0.25}
# {'bin': 53, 'shift': 0.5}
# {'bin': 54, 'shift': 0.75}
# {'bin': 55, 'shift': 0.75}
# {'bin': 56, 'shift': 0.5}
# {'bin': 57, 'shift': 0.0}
# {'bin': 58, 'shift': 0.75}
# {'bin': 59, 'shift': 0.0}
# {'bin': 60, 'shift': 0.75}
# {'bin': 61, 'shift': 0.25}
# {'bin': 62, 'shift': 0.75}
# {'bin': 63, 'shift': 0.25}
# {'bin': 64, 'shift': 0.0}
# {'bin': 65, 'shift': 0.5}
# {'bin': 66, 'shift': 0.5}
# {'bin': 67, 'shift': 0.5}
# {'bin': 68, 'shift': 0.5}
# {'bin': 69, 'shift': 0.25}
# {'bin': 70, 'shift': 0.75}
# {'bin': 71, 'shift': 0.0}
# {'bin': 72, 'shift': 0.0}
# {'bin': 73, 'shift': 0.0}
# {'bin': 74, 'shift': 0.25}
# {'bin': 75, 'shift': 0.5}
# {'bin': 76, 'shift': 0.25}
# {'bin': 77, 'shift': 0.75}
# {'bin': 78, 'shift': 0.25}
# {'bin': 79, 'shift': 0.5}
# {'bin': 80, 'shift': 0.75}
# {'bin': 81, 'shift': 0.0}
# {'bin': 82, 'shift': 0.0}
# {'bin': 83, 'shift': 0.25}
# {'bin': 84, 'shift': 0.0}
# {'bin': 85, 'shift': 0.0}
# {'bin': 86, 'shift': 0.25}
# {'bin': 87, 'shift': 0.0}
# {'bin': 88, 'shift': 0.5}
# {'bin': 89, 'shift': 0.0}
# {'bin': 90, 'shift': 0.0}
# {'bin': 91, 'shift': 0.75}
# {'bin': 92, 'shift': 0.5}
# {'bin': 93, 'shift': 0.25}
# {'bin': 94, 'shift': 0.25}
# {'bin': 95, 'shift': 0.0}
# {'bin': 96, 'shift': 0.75}
# {'bin': 97, 'shift': 0.0}
# {'bin': 98, 'shift': 0.25}
# {'bin': 99, 'shift': 0.75}
# ...
# {'bin': 445, 'shift': 0.25}
# {'bin': 446, 'shift': 0.75}
# {'bin': 447, 'shift': 0.25}
# {'bin': 448, 'shift': 0.75}
# {'bin': 449, 'shift': 0.0}
# {'bin': 450, 'shift': 0.75}
# {'bin': 451, 'shift': 0.25}
# {'bin': 452, 'shift': 0.5}
# {'bin': 453, 'shift': 0.25}
# {'bin': 454, 'shift': 0.25}
# {'bin': 455, 'shift': 0.75}
# {'bin': 456, 'shift': 0.0}
# {'bin': 457, 'shift': 0.0}
# {'bin': 458, 'shift': 0.5}
# {'bin': 459, 'shift': 0.75}
# {'bin': 460, 'shift': 0.75}
# {'bin': 461, 'shift': 0.75}
# {'bin': 462, 'shift': 0.0}
# {'bin': 463, 'shift': 0.75}
# {'bin': 464, 'shift': 0.0}
# {'bin': 465, 'shift': 0.5}
# {'bin': 466, 'shift': 0.75}
# {'bin': 467, 'shift': 0.5}
# {'bin': 468, 'shift': 0.75}
# {'bin': 469, 'shift': 0.5}
# {'bin': 470, 'shift': 0.75}
# {'bin': 471, 'shift': 0.25}
# {'bin': 472, 'shift': 0.75}
# {'bin': 473, 'shift': 0.75}
# {'bin': 474, 'shift': 0.0}
# {'bin': 475, 'shift': 0.75}
# {'bin': 476, 'shift': 0.75}
# {'bin': 477, 'shift': 0.0}
# {'bin': 478, 'shift': 0.25}
# {'bin': 479, 'shift': 0.5}
# {'bin': 480, 'shift': 0.75}
# {'bin': 481, 'shift': 0.25}
# {'bin': 482, 'shift': 0.5}
# {'bin': 483, 'shift': 0.75}
# {'bin': 484, 'shift': 0.5}
# {'bin': 485, 'shift': 0.75}
# {'bin': 486, 'shift': 0.5}
# {'bin': 487, 'shift': 0.0}
# {'bin': 488, 'shift': 0.25}
# {'bin': 489, 'shift': 0.25}
# {'bin': 490, 'shift': 0.5}
# {'bin': 491, 'shift': 0.75}
# {'bin': 492, 'shift': 0.5}
# {'bin': 493, 'shift': 0.0}
# {'bin': 494, 'shift': 0.5}
# {'bin': 495, 'shift': 0.5}
# {'bin': 496, 'shift': 0.25}
# {'bin': 497, 'shift': 0.0}
# {'bin': 498, 'shift': 0.0}
# {'bin': 499, 'shift': 0.75}
# {'bin': 500, 'shift': 0.5}
# {'bin': 501, 'shift': 0.0}
# {'bin': 502, 'shift': 0.75}
# {'bin': 503, 'shift': 0.5}
# {'bin': 504, 'shift': 0.25}
# {'bin': 505, 'shift': 0.25}
# {'bin': 506, 'shift': 0.0}
# {'bin': 507, 'shift': 0.25}
# {'bin': 508, 'shift': 0.5}
# {'bin': 509, 'shift': 0.5}
# {'bin': 510, 'shift': 0.5}
# {'bin': 511, 'shift': 0.25}
# {'bin': 512, 'shift': 0.0}
# {'bin': 513, 'shift': 0.5}
# {'bin': 514, 'shift': 0.75}
# {'bin': 515, 'shift': 0.5}
# {'bin': 516, 'shift': 0.5}
# {'bin': 517, 'shift': 0.5}
# {'bin': 518, 'shift': 0.25}
# {'bin': 519, 'shift': 0.75}
# {'bin': 520, 'shift': 0.25}
# {'bin': 521, 'shift': 0.75}
# {'bin': 522, 'shift': 0.25}
# {'bin': 523, 'shift': 0.25}
# {'bin': 524, 'shift': 0.0}
# {'bin': 525, 'shift': 0.25}
# {'bin': 526, 'shift': 0.5}
# {'bin': 527, 'shift': 0.25}
# {'bin': 528, 'shift': 0.75}
# {'bin': 529, 'shift': 0.25}
# {'bin': 530, 'shift': 0.75}
# {'bin': 531, 'shift': 0.5}
# {'bin': 532, 'shift': 0.25}
# {'bin': 533, 'shift': 0.25}
# {'bin': 534, 'shift': 0.0}
# {'bin': 535, 'shift': 0.0}
# {'bin': 536, 'shift': 0.25}
# {'bin': 537, 'shift': 0.25}
# {'bin': 538, 'shift': 0.5}
# {'bin': 539, 'shift': 0.5}
# {'bin': 540, 'shift': 0.0}
# {'bin': 541, 'shift': 0.0}
# {'bin': 542, 'shift': 0.5}
# {'bin': 543, 'shift': 0.25}
# {'bin': 544, 'shift': 0.5}
# {'bin': 545, 'shift': 0.25}
# {'bin': 546, 'shift': 0.25}
# {'bin': 547, 'shift': 0.75}
# {'bin': 548, 'shift': 0.5}
# {'bin': 549, 'shift': 0.0}
# {'bin': 550, 'shift': 0.0}
# {'bin': 551, 'shift': 0.25}
# {'bin': 552, 'shift': 0.5}
# {'bin': 553, 'shift': 0.25}
# {'bin': 554, 'shift': 0.5}
# {'bin': 555, 'shift': 0.25}
# {'bin': 556, 'shift': 0.0}
# {'bin': 557, 'shift': 0.5}
# {'bin': 558, 'shift': 0.5}
# {'bin': 559, 'shift': 0.75}
# {'bin': 560, 'shift': 0.5}
# {'bin': 561, 'shift': 0.25}
# {'bin': 562, 'shift': 0.5}
# {'bin': 563, 'shift': 0.75}
# {'bin': 564, 'shift': 0.75}
# {'bin': 565, 'shift': 0.75}
# {'bin': 566, 'shift': 0.75}
# {'bin': 567, 'shift': 0.5}
# {'bin': 568, 'shift': 0.5}
# {'bin': 569, 'shift': 0.25}
# {'bin': 570, 'shift': 0.75}
# {'bin': 571, 'shift': 0.0}
# {'bin': 572, 'shift': 0.25}
# {'bin': 573, 'shift': 0.25}
# {'bin': 574, 'shift': 0.75}
# {'bin': 575, 'shift': 0.0}
# {'bin': 576, 'shift': 0.75}
# {'bin': 577, 'shift': 0.5}
# {'bin': 578, 'shift': 0.5}
# {'bin': 579, 'shift': 0.5}
# {'bin': 580, 'shift': 0.25}
# {'bin': 581, 'shift': 0.25}
# {'bin': 582, 'shift': 0.25}
# {'bin': 583, 'shift': 0.25}
# {'bin': 584, 'shift': 0.75}
# {'bin': 585, 'shift': 0.5}
# {'bin': 586, 'shift': 0.0}
# {'bin': 587, 'shift': 0.5}
# {'bin': 588, 'shift': 0.75}
# {'bin': 589, 'shift': 0.75}
# {'bin': 590, 'shift': 0.5}
# {'bin': 591, 'shift': 0.0}
# {'bin': 592, 'shift': 0.75}
# {'bin': 593, 'shift': 0.75}
# {'bin': 594, 'shift': 0.5}
# {'bin': 595, 'shift': 0.75}
# {'bin': 596, 'shift': 0.5}
# {'bin': 597, 'shift': 0.75}
# {'bin': 598, 'shift': 0.5}
# {'bin': 599, 'shift': 0.5}
# {'bin': 600, 'shift': 0.75}
# {'bin': 601, 'shift': 0.5}
# {'bin': 602, 'shift': 0.5}
# {'bin': 603, 'shift': 0.25}
# {'bin': 604, 'shift': 0.25}
# {'bin': 605, 'shift': 0.5}
# {'bin': 606, 'shift': 0.25}
# {'bin': 607, 'shift': 0.25}
# {'bin': 608, 'shift': 0.5}
# {'bin': 609, 'shift': 0.5}
# {'bin': 610, 'shift': 0.75}
# {'bin': 611, 'shift': 0.75}
# {'bin': 612, 'shift': 0.0}
# {'bin': 613, 'shift': 0.0}
# {'bin': 614, 'shift': 0.75}
# {'bin': 615, 'shift': 0.75}
# {'bin': 616, 'shift': 0.0}
# {'bin': 617, 'shift': 0.75}
# {'bin': 618, 'shift': 0.5}
# {'bin': 619, 'shift': 0.25}
# {'bin': 620, 'shift': 0.25}
# {'bin': 621, 'shift': 0.0}
# {'bin': 622, 'shift': 0.5}
# {'bin': 623, 'shift': 0.0}
# {'bin': 624, 'shift': 0.5}
# {'bin': 625, 'shift': 0.5}
# {'bin': 626, 'shift': 0.25}
# {'bin': 627, 'shift': 0.0}
# {'bin': 628, 'shift': 0.75}
# {'bin': 629, 'shift': 0.5}
# {'bin': 630, 'shift': 0.75}
# {'bin': 631, 'shift': 0.0}
# {'bin': 632, 'shift': 0.5}
# {'bin': 633, 'shift': 0.5}
# {'bin': 634, 'shift': 0.75}
# {'bin': 635, 'shift': 0.5}
# {'bin': 636, 'shift': 0.25}
# {'bin': 637, 'shift': 0.25}
# {'bin': 638, 'shift': 0.0}
# {'bin': 639, 'shift': 0.0}
# {'bin': 640, 'shift': 0.25}
# {'bin': 641, 'shift': 0.5}
# {'bin': 642, 'shift': 0.0}
# {'bin': 643, 'shift': 0.25}
# {'bin': 644, 'shift': 0.75}
# {'bin': 645, 'shift': 0.5}
# {'bin': 646, 'shift': 0.25}
# {'bin': 647, 'shift': 0.5}
# {'bin': 648, 'shift': 0.5}
# {'bin': 649, 'shift': 0.0}
# {'bin': 650, 'shift': 0.5}
# {'bin': 651, 'shift': 0.25}
# {'bin': 652, 'shift': 0.25}
# {'bin': 653, 'shift': 0.25}
# {'bin': 654, 'shift': 0.25}
# {'bin': 655, 'shift': 0.5}
# {'bin': 656, 'shift': 0.0}
# {'bin': 657, 'shift': 0.25}
# {'bin': 658, 'shift': 0.5}
# {'bin': 659, 'shift': 0.75}
# {'bin': 660, 'shift': 0.0}
# {'bin': 661, 'shift': 0.5}
# {'bin': 662, 'shift': 0.25}
# {'bin': 663, 'shift': 0.0}
# {'bin': 664, 'shift': 0.5}
# {'bin': 665, 'shift': 0.75}
# {'bin': 666, 'shift': 0.25}
# {'bin': 667, 'shift': 0.25}
# {'bin': 668, 'shift': 0.0}
# {'bin': 669, 'shift': 0.5}
# {'bin': 670, 'shift': 0.25}
# {'bin': 671, 'shift': 0.75}
# {'bin': 672, 'shift': 0.0}
# {'bin': 673, 'shift': 0.0}
# {'bin': 674, 'shift': 0.75}
# {'bin': 675, 'shift': 0.25}
# {'bin': 676, 'shift': 0.5}
# {'bin': 677, 'shift': 0.25}
# {'bin': 678, 'shift': 0.5}
# {'bin': 679, 'shift': 0.75}
# {'bin': 680, 'shift': 0.0}
# {'bin': 681, 'shift': 0.75}
# {'bin': 682, 'shift': 0.75}
# {'bin': 683, 'shift': 0.0}
# {'bin': 684, 'shift': 0.25}
# {'bin': 685, 'shift': 0.75}
# {'bin': 686, 'shift': 0.0}
# {'bin': 687, 'shift': 0.0}
# {'bin': 688, 'shift': 0.75}
# {'bin': 689, 'shift': 0.25}
# {'bin': 690, 'shift': 0.75}
# {'bin': 691, 'shift': 0.0}
# {'bin': 692, 'shift': 0.75}
# {'bin': 693, 'shift': 0.75}
# {'bin': 694, 'shift': 0.0}
# {'bin': 695, 'shift': 0.0}
# {'bin': 696, 'shift': 0.25}
# {'bin': 697, 'shift': 0.5}
# {'bin': 698, 'shift': 0.75}
# {'bin': 699, 'shift': 0.75}
# {'bin': 700, 'shift': 0.25}
# {'bin': 701, 'shift': 0.25}
# {'bin': 702, 'shift': 0.75}
# {'bin': 703, 'shift': 0.75}
# {'bin': 704, 'shift': 0.0}
# {'bin': 705, 'shift': 0.0}
# {'bin': 706, 'shift': 0.75}
# {'bin': 707, 'shift': 0.75}
# {'bin': 708, 'shift': 0.25}
# {'bin': 709, 'shift': 0.25}
# {'bin': 710, 'shift': 0.75}
# {'bin': 711, 'shift': 0.0}
# {'bin': 712, 'shift': 0.0}
# {'bin': 713, 'shift': 0.0}
# {'bin': 714, 'shift': 0.5}
# {'bin': 715, 'shift': 0.75}
# {'bin': 716, 'shift': 0.75}
# {'bin': 717, 'shift': 0.5}
# {'bin': 718, 'shift': 0.0}
# {'bin': 719, 'shift': 0.0}
# {'bin': 720, 'shift': 0.75}
# {'bin': 721, 'shift': 0.5}
# {'bin': 722, 'shift': 0.0}
# {'bin': 723, 'shift': 0.0}
# {'bin': 724, 'shift': 0.0}
# {'bin': 725, 'shift': 0.0}
# {'bin': 726, 'shift': 0.75}
# {'bin': 727, 'shift': 0.25}
# {'bin': 728, 'shift': 0.25}
# {'bin': 729, 'shift': 0.25}
# {'bin': 730, 'shift': 0.5}
# {'bin': 731, 'shift': 0.5}
# {'bin': 732, 'shift': 0.75}
# {'bin': 733, 'shift': 0.25}
# {'bin': 734, 'shift': 0.25}
# {'bin': 735, 'shift': 0.5}
# {'bin': 736, 'shift': 0.75}
# {'bin': 737, 'shift': 0.5}
# {'bin': 738, 'shift': 0.5}
# {'bin': 739, 'shift': 0.0}
# {'bin': 740, 'shift': 0.75}
# {'bin': 741, 'shift': 0.5}
# {'bin': 742, 'shift': 0.25}
# {'bin': 743, 'shift': 0.0}
# {'bin': 744, 'shift': 0.0}
# {'bin': 745, 'shift': 0.25}
# {'bin': 746, 'shift': 0.25}
# {'bin': 747, 'shift': 0.75}
# {'bin': 748, 'shift': 0.5}
# {'bin': 749, 'shift': 0.25}
# {'bin': 750, 'shift': 0.75}
# {'bin': 751, 'shift': 0.0}
# {'bin': 752, 'shift': 0.5}
# {'bin': 753, 'shift': 0.25}
# {'bin': 754, 'shift': 0.0}
# {'bin': 755, 'shift': 0.25}
# {'bin': 756, 'shift': 0.25}
# {'bin': 757, 'shift': 0.25}
# {'bin': 758, 'shift': 0.75}
# {'bin': 759, 'shift': 0.0}
# {'bin': 760, 'shift': 0.25}
# {'bin': 761, 'shift': 0.0}
# {'bin': 762, 'shift': 0.0}
# {'bin': 763, 'shift': 0.0}
# {'bin': 764, 'shift': 0.25}
# {'bin': 765, 'shift': 0.75}
# {'bin': 766, 'shift': 0.75}
# {'bin': 767, 'shift': 0.75}
# {'bin': 768, 'shift': 0.0}
# {'bin': 769, 'shift': 0.25}
# {'bin': 770, 'shift': 0.5}
# {'bin': 771, 'shift': 0.5}
# {'bin': 772, 'shift': 0.75}
# {'bin': 773, 'shift': 0.0}
# {'bin': 774, 'shift': 0.5}
# {'bin': 775, 'shift': 0.25}
# {'bin': 776, 'shift': 0.75}
# {'bin': 777, 'shift': 0.75}
# {'bin': 778, 'shift': 0.5}
# {'bin': 779, 'shift': 0.75}
# {'bin': 780, 'shift': 0.0}
# {'bin': 781, 'shift': 0.75}
# {'bin': 782, 'shift': 0.5}
# {'bin': 783, 'shift': 0.0}
# {'bin': 784, 'shift': 0.75}
# {'bin': 785, 'shift': 0.75}
# {'bin': 786, 'shift': 0.5}
# {'bin': 787, 'shift': 0.25}
# {'bin': 788, 'shift': 0.5}
# {'bin': 789, 'shift': 0.5}
# {'bin': 790, 'shift': 0.25}
# {'bin': 791, 'shift': 0.25}
# {'bin': 792, 'shift': 0.25}
# {'bin': 793, 'shift': 0.5}
# {'bin': 794, 'shift': 0.0}
# {'bin': 795, 'shift': 0.25}
# {'bin': 796, 'shift': 0.75}
# {'bin': 797, 'shift': 0.5}
# {'bin': 798, 'shift': 0.5}
# {'bin': 799, 'shift': 0.5}
# {'bin': 800, 'shift': 0.75}
# {'bin': 801, 'shift': 0.25}
# {'bin': 802, 'shift': 0.75}
# {'bin': 803, 'shift': 0.75}
# {'bin': 804, 'shift': 0.25}
# {'bin': 805, 'shift': 0.25}
# {'bin': 806, 'shift': 0.5}
# {'bin': 807, 'shift': 0.0}
# {'bin': 808, 'shift': 0.0}
# {'bin': 809, 'shift': 0.75}
# {'bin': 810, 'shift': 0.0}
# {'bin': 811, 'shift': 0.75}
# {'bin': 812, 'shift': 0.75}
# {'bin': 813, 'shift': 0.25}
# {'bin': 814, 'shift': 0.0}
# {'bin': 815, 'shift': 0.25}
# {'bin': 816, 'shift': 0.75}
# {'bin': 817, 'shift': 0.75}
# {'bin': 818, 'shift': 0.75}
# {'bin': 819, 'shift': 0.5}
# {'bin': 820, 'shift': 0.75}
# {'bin': 821, 'shift': 0.5}
# {'bin': 822, 'shift': 0.5}
# {'bin': 823, 'shift': 0.5}
# {'bin': 824, 'shift': 0.5}
# {'bin': 825, 'shift': 0.0}
# {'bin': 826, 'shift': 0.5}
# {'bin': 827, 'shift': 0.0}
# {'bin': 828, 'shift': 0.0}
# {'bin': 829, 'shift': 0.75}
# {'bin': 830, 'shift': 0.5}
# {'bin': 831, 'shift': 0.75}
# {'bin': 832, 'shift': 0.75}
# {'bin': 833, 'shift': 0.25}
# {'bin': 834, 'shift': 0.75}
# {'bin': 835, 'shift': 0.25}
# {'bin': 836, 'shift': 0.0}
# {'bin': 837, 'shift': 0.25}
# {'bin': 838, 'shift': 0.25}
# {'bin': 839, 'shift': 0.5}
# {'bin': 840, 'shift': 0.0}
# {'bin': 841, 'shift': 0.75}
# {'bin': 842, 'shift': 0.75}
# {'bin': 843, 'shift': 0.0}
# {'bin': 844, 'shift': 0.5}
# {'bin': 845, 'shift': 0.0}
# {'bin': 846, 'shift': 0.0}
# {'bin': 847, 'shift': 0.25}
# {'bin': 848, 'shift': 0.0}
# {'bin': 849, 'shift': 0.75}
# {'bin': 850, 'shift': 0.75}
# {'bin': 851, 'shift': 0.25}
# {'bin': 852, 'shift': 0.75}
# {'bin': 853, 'shift': 0.75}
# {'bin': 854, 'shift': 0.75}
# {'bin': 855, 'shift': 0.0}
# {'bin': 856, 'shift': 0.5}
# {'bin': 857, 'shift': 0.0}
# {'bin': 858, 'shift': 0.0}
# {'bin': 859, 'shift': 0.25}
# {'bin': 860, 'shift': 0.5}
# {'bin': 861, 'shift': 0.25}
# {'bin': 862, 'shift': 0.25}
# {'bin': 863, 'shift': 0.25}
# {'bin': 864, 'shift': 0.75}
# {'bin': 865, 'shift': 0.0}
# {'bin': 866, 'shift': 0.75}
# {'bin': 867, 'shift': 0.75}
# {'bin': 868, 'shift': 0.25}
# {'bin': 869, 'shift': 0.5}
# {'bin': 870, 'shift': 0.75}
# {'bin': 871, 'shift': 0.5}
# {'bin': 872, 'shift': 0.0}
# {'bin': 873, 'shift': 0.0}
# {'bin': 874, 'shift': 0.75}
# {'bin': 875, 'shift': 0.5}
# {'bin': 876, 'shift': 0.0}
# {'bin': 877, 'shift': 0.5}
# {'bin': 878, 'shift': 0.75}
# {'bin': 879, 'shift': 0.75}
# {'bin': 880, 'shift': 0.0}
# {'bin': 881, 'shift': 0.5}
# {'bin': 882, 'shift': 0.75}
# {'bin': 883, 'shift': 0.5}
# {'bin': 884, 'shift': 0.0}
# {'bin': 885, 'shift': 0.0}
# {'bin': 886, 'shift': 0.0}
# {'bin': 887, 'shift': 0.25}
# {'bin': 888, 'shift': 0.75}
# {'bin': 889, 'shift': 0.75}
# {'bin': 890, 'shift': 0.0}
# {'bin': 891, 'shift': 0.5}
# {'bin': 892, 'shift': 0.5}
# {'bin': 893, 'shift': 0.0}
# {'bin': 894, 'shift': 0.25}
# {'bin': 895, 'shift': 0.5}
# {'bin': 896, 'shift': 0.75}
# {'bin': 897, 'shift': 0.5}
# {'bin': 898, 'shift': 0.25}
# {'bin': 899, 'shift': 0.0}
# {'bin': 900, 'shift': 0.25}
# {'bin': 901, 'shift': 0.5}
# {'bin': 902, 'shift': 0.0}
# {'bin': 903, 'shift': 0.5}
# {'bin': 904, 'shift': 0.25}
# {'bin': 905, 'shift': 0.0}
# {'bin': 906, 'shift': 0.75}
# {'bin': 907, 'shift': 0.0}
# {'bin': 908, 'shift': 0.5}
# {'bin': 909, 'shift': 0.75}
# {'bin': 910, 'shift': 0.75}
# {'bin': 911, 'shift': 0.25}
# {'bin': 912, 'shift': 0.5}
# {'bin': 913, 'shift': 0.75}
# {'bin': 914, 'shift': 0.25}
# {'bin': 915, 'shift': 0.75}
# {'bin': 916, 'shift': 0.75}
# {'bin': 917, 'shift': 0.25}
# {'bin': 918, 'shift': 0.25}
# {'bin': 919, 'shift': 0.75}
# {'bin': 920, 'shift': 0.75}
# {'bin': 921, 'shift': 0.5}
# {'bin': 922, 'shift': 0.0}
# {'bin': 923, 'shift': 0.5}
# {'bin': 924, 'shift': 0.75}
# {'bin': 925, 'shift': 0.25}
# {'bin': 926, 'shift': 0.25}
# {'bin': 927, 'shift': 0.75}
# {'bin': 928, 'shift': 0.5}
# {'bin': 929, 'shift': 0.0}
# {'bin': 930, 'shift': 0.25}
# {'bin': 931, 'shift': 0.75}
# {'bin': 932, 'shift': 0.25}
# {'bin': 933, 'shift': 0.0}
# {'bin': 934, 'shift': 0.25}
# {'bin': 935, 'shift': 0.5}
# {'bin': 936, 'shift': 0.75}
# {'bin': 937, 'shift': 0.75}
# {'bin': 938, 'shift': 0.5}
# {'bin': 939, 'shift': 0.75}
# {'bin': 940, 'shift': 0.5}
# {'bin': 941, 'shift': 0.0}
# {'bin': 942, 'shift': 0.75}
# {'bin': 943, 'shift': 0.75}
# {'bin': 944, 'shift': 0.75}
# {'bin': 945, 'shift': 0.0}
# {'bin': 946, 'shift': 0.0}
# {'bin': 947, 'shift': 0.75}
# {'bin': 948, 'shift': 0.5}
# {'bin': 949, 'shift': 0.0}
# {'bin': 950, 'shift': 0.75}
# {'bin': 951, 'shift': 0.75}
# {'bin': 952, 'shift': 0.25}
# {'bin': 953, 'shift': 0.0}
# {'bin': 954, 'shift': 0.5}
# {'bin': 955, 'shift': 0.5}
# {'bin': 956, 'shift': 0.0}
# {'bin': 957, 'shift': 0.75}
# {'bin': 958, 'shift': 0.25}
# {'bin': 959, 'shift': 0.0}
# {'bin': 960, 'shift': 0.25}
# {'bin': 961, 'shift': 0.75}
# {'bin': 962, 'shift': 0.25}
# {'bin': 963, 'shift': 0.5}
# {'bin': 964, 'shift': 0.75}
# {'bin': 965, 'shift': 0.5}
# {'bin': 966, 'shift': 0.75}
# {'bin': 967, 'shift': 0.5}
# {'bin': 968, 'shift': 0.5}
# {'bin': 969, 'shift': 0.25}
# {'bin': 970, 'shift': 0.75}
# {'bin': 971, 'shift': 0.0}
# {'bin': 972, 'shift': 0.75}
# {'bin': 973, 'shift': 0.25}
# {'bin': 974, 'shift': 0.5}
# {'bin': 975, 'shift': 0.0}
# {'bin': 976, 'shift': 0.0}
# {'bin': 977, 'shift': 0.25}
# {'bin': 978, 'shift': 0.25}
# {'bin': 979, 'shift': 0.25}
# {'bin': 980, 'shift': 0.5}
# {'bin': 981, 'shift': 0.0}
# {'bin': 982, 'shift': 0.0}
# {'bin': 983, 'shift': 0.5}
# {'bin': 984, 'shift': 0.0}
# {'bin': 985, 'shift': 0.75}
# {'bin': 986, 'shift': 0.75}
# {'bin': 987, 'shift': 0.75}
# {'bin': 988, 'shift': 0.25}
# {'bin': 989, 'shift': 0.0}
# {'bin': 990, 'shift': 0.75}
# {'bin': 991, 'shift': 0.0}
# {'bin': 992, 'shift': 0.75}
# {'bin': 993, 'shift': 0.25}
# {'bin': 994, 'shift': 0.0}
# {'bin': 995, 'shift': 0.25}
# {'bin': 996, 'shift': 0.75}
# {'bin': 997, 'shift': 0.5}
# {'bin': 998, 'shift': 0.75}
# {'bin': 999, 'shift': 0.25}
# {'bin': 1000, 'shift': 0.5}
# {'bin': 1001, 'shift': 0.5}
# {'bin': 1002, 'shift': 0.5}
# {'bin': 1003, 'shift': 0.25}
# {'bin': 1004, 'shift': 0.75}
# {'bin': 1005, 'shift': 0.75}
# {'bin': 1006, 'shift': 0.25}
# {'bin': 1007, 'shift': 0.25}
# {'bin': 1008, 'shift': 0.0}
# {'bin': 1009, 'shift': 0.0}
# {'bin': 1010, 'shift': 0.25}
# {'bin': 1011, 'shift': 0.75}
# {'bin': 1012, 'shift': 0.0}
# {'bin': 1013, 'shift': 0.5}
# {'bin': 1014, 'shift': 0.5}
# {'bin': 1015, 'shift': 0.25}
# {'bin': 1016, 'shift': 0.5}
# {'bin': 1017, 'shift': 0.0}
# {'bin': 1018, 'shift': 0.5}
# {'bin': 1019, 'shift': 0.75}
# {'bin': 1020, 'shift': 0.5}
# {'bin': 1021, 'shift': 0.75}
# {'bin': 1022, 'shift': 0.25}
# {'bin': 1023, 'shift': 0.0}
# {'bin': 1024, 'shift': 0.0}
